# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
sns.set_style("darkgrid")

# %% [markdown]
# # Context

# %%
synthanic_data = pd.read_csv("train.csv")

# %%
synthanic_data
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked
# ...

# %% [markdown]
# # Data quality assessment

# %%
synthanic_data.info()
pd.isna(synthanic_data).sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  object
#  5   Age          96708 non-null   float64
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       95377 non-null   object
#  9   Fare         99866 non-null   float64
#  10  Cabin        32134 non-null   object
#  11  Embarked     99750 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 9.2+ MB
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age             3292
# SibSp              0
# Parch              0
# Ticket          4623
# ...

# %% [markdown]
# # Data exploration

# %%
synthanic_by_Survived	= synthanic_data.groupby(['Survived']).sum()
synthanic_by_Survived
# Out:
#           PassengerId  Pclass         Age  SibSp  Parch        Fare
# Survived
# 0          2858478394  132578  2029623.74  23082  24915  1865903.48
# 1          2141471606   78113  1679657.26  16687  20541  2521143.03

# %%
synthanic_by_Pclass	= synthanic_data.groupby(['Pclass']).sum()
synthanic_by_Pclass
# Out:
#         PassengerId  Survived         Age  SibSp  Parch        Fare
# Pclass
# 1        1517227148     17576  1314264.84  14137  15678  2805073.01
# 2        1433110370     15057  1071282.84  10960  12571   737574.67
# 3        2049612482     10141  1323733.32  14672  17207   844398.83

# %%
sns.lineplot(synthanic_data.SibSp,synthanic_data.Age, data = synthanic_data )
plt.ylabel('Age')
plt.xlabel('SibSp')
# Out:
# Text(0.5, 0, 'SibSp')

# %% [markdown]
# # Summary

# %%
The greatest number of rescues was among the 1st class
The lowest number of relatives was among people over 36
